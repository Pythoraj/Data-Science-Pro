# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use("dark_background")

# %%
x = np.random.randn(50)
y = np.random.randn(50)

# %%
x
# Out:
# array([ 1.25105607e+00, -9.62013687e-01, -8.34914336e-02, -4.51170492e-01,
#         1.06323195e-01, -1.13029066e+00,  5.08076848e-01, -4.25736503e-02,
#         3.12289401e-01,  4.20392216e-01, -1.72108053e+00, -2.63427190e-01,
#        -8.88189210e-01, -8.57554311e-01,  1.45376717e+00,  1.64577966e-01,
#         1.45953238e+00,  4.55127564e-01, -2.48336798e-02,  6.03447728e-01,
#         1.91471160e-01,  4.85761839e-01,  4.02506946e-01, -2.15552885e+00,
#         1.15690480e-01, -7.96847485e-04,  1.12503882e+00, -8.57404639e-02,
#        -3.11306769e-01, -4.05669071e-01, -5.25297887e-01,  6.80952477e-01,
#        -1.69785910e-02, -7.06952974e-01,  2.75533859e-01,  9.20704225e-01,
#         6.35553780e-01, -1.43624013e+00,  1.46673482e+00,  5.24148593e-01,
#        -1.41526226e+00,  1.40227847e+00, -9.01128338e-01,  9.83537479e-01,
#         1.12238986e+00, -1.26520949e+00, -3.24827195e-01, -1.19547324e+00,
#        -1.29996844e+00, -4.00575915e-01])

# %%
y
# Out:
# array([ 1.4433385 , -0.1205227 , -0.61605887,  1.58944493, -0.80854436,
#        -0.70564034,  1.49017443,  1.21207263,  1.80295603, -0.82072685,
#         1.17657192,  0.98447208,  2.57034742, -0.0441859 ,  1.76719008,
#         0.68684871,  0.54361828, -0.43756246,  0.30349896,  0.9817521 ,
#         0.05239458,  2.42573604, -0.89299458,  0.64159399,  0.74029078,
#         1.6398475 , -0.16953299, -0.01175067,  1.28737598,  1.2175298 ,
#         0.50876325,  0.433094  ,  0.2104012 , -1.85231331, -0.87022397,
#        -1.53182768, -1.04293543,  1.39096618, -0.62082204,  0.76141126,
#         0.05918453, -0.0783433 ,  0.07456838,  0.3359207 ,  0.03330114,
#        -0.44726311, -0.91359962,  0.08527075, -0.22639673, -0.33093963])

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame(np.random.randn(1000), columns=['Data'], index = pd.date_range('13-02-2024', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-02-13 -0.782138
# 2024-02-14 -1.411700
# 2024-02-15  0.081701
# 2024-02-16  1.445954
# 2024-02-17  0.906757
# ...              ...
# 2026-11-04  1.007733
# 2026-11-05 -0.210596
# 2026-11-06 -0.235136
# 2026-11-07  0.434863
# 2026-11-08  0.756791
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (30,8))
# Out:
# <Axes: >

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y = np.linspace(0,10,100)

# %%
y
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
z = np.linspace(0,10,100)

# %%
z
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.plot(x, np.tan(x))
plt.show()

# %%
plt.plot(y,np.sin(y))
plt.plot(y,np.cos(y))
plt.show()

# %%
plt.plot(x, np.sin(x), '--')
plt.plot(x, np.cos(x), '*')
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x, np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
#plt.plot(x)
plt.plot(x)

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))

plt.subplot(2,2,4)
plt.plot(x, np.tan(x+1))

plt.show()

# %%
plt.figure()           # It will create a new figure or exicuted existing figure
plt.subplot(3,3,1)     # Here we have divided a plot into 3x3 formate where first three is rows and second 3 is columns. 1 indicated as index
plt.plot(x, np.sin(x), '|', color='r') # this is is the main plot

plt.subplot(3,3,2)     # 3-rows, 3-columns and index position is 2
plt.plot(x, np.cos(x), color = 'g')

plt.subplot(3,3,3)     # 3-rows, 3-columns and index position is 3 
plt.plot(x, np.tan(x), color = 'y')

plt.subplot(3,3,4)     # 3-rows, 3-columns and index position is 4
plt.plot(x, np.sin(x+1), color = 'b')

plt.subplot(3,3,5)     # 3-rows, 3-columns and index position is 5
plt.plot(x, np.cos(x+1), color = 'w')

plt.subplot(3,3,6)     # 3-rows, 3-columns and index position is 6
plt.plot(x, np.tan(x+1), color = 'm')

plt.subplot(3,3,7)     # 3-rows, 3-columns and index position is 7
plt.plot(x, np.sin(x+2), color = 'c')

plt.subplot(3,3,8)     # 3-rows, 3-columns and index position is 8
plt.plot(x, np.cos(x+2), color = '#d703fc')

plt.subplot(3,3,9)     # 3-rows, 3-columns and index position is 9
plt.plot(x, np.tan(x+2), color = '#fcad03')

plt.show()

# %%
# Column-wise data representation in plot

plt.figure()
plt.subplot(2,1,1)
plt.plot(x, np.sin(x), scalex=True, scaley=True)

plt.subplot(2,1,2)
plt.plot(x,np.cos(x),scalex=True, scaley=True)

plt.show()

# %%
# scale the plot size

f = plt.figure()

f.set_figwidth(4)
f.set_figheight(1)

plt.subplot(2,1,1)
plt.plot(x, np.sin(x), scalex=True, scaley=True)

plt.subplot(2,1,2)
plt.plot(x,np.cos(x),scalex=True, scaley=True)

plt.show()

# %%
plt.figure()
plt.plot(x,np.sin(x), color = 'r')
plt.xlim(0,15)
plt.ylim(-1.5,1.5)
#plt.axis('equal')
plt.show()

# %%
plt.figure()
plt.plot(x,np.sin(x), color = 'r')
plt.xlim(0,15)
plt.ylim(-1.5,1.5)
plt.axis('equal')
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x, np.sin(x), color = 'r')
plt.axis('equal')
plt.xlim(1,15)
plt.ylim(-1.5,1.5)
plt.grid()

plt.show()

# %%
plt.figure()
plt.plot(x, np.sin(x), color = 'b')
plt.xlim(1, 15)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axis('equal')
plt.title("This is sin plot before real dataset execution to understand basic syntax", color = 'r',loc='center')

plt.show()

# %%
plt.figure()
plt.plot(x, np.sin(x), color = 'g')
plt.xlim(1,15)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axis('equal')
plt.title('This is sin plot before real dataset execution to understand basic syntax', color = "y")
plt.xlabel("X-Axis", color = 'b')
plt.ylabel("Y-Axis", color = 'b')
plt.show()

# %%
plt.figure()
plt.plot(x, np.sin(x-0), color = 'g', label = 'X-Axis')
plt.plot(x, np.cos(x-0), color = 'y', label = 'Y-Axis')
plt.xlim(1,15)
plt.ylim(-1.5,1.5)
plt.xlabel('X-Axis', color = 'y')
plt.ylabel('Y-Axis', color = 'y')
plt.grid(color = 'r')
plt.axis('equal')
plt.title("This is sin plot before real dataset execution to understand basic syntax", color = 'b')
plt.legend()
plt.show()

# %%
# Legend function: A legend is a predefined function legend() that creates an area on the graph which describes all the elements of a graph.

plt.figure()
plt.plot(x, np.sin(x+1), color= 'g', label = "X-Axis")
plt.plot(x, np.cos(x+1), color= 'r', label = "Y-Axis")
plt.xlim(1,15)
plt.ylim(-1.5, 1.5)
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.grid(color = 'b')
plt.title('This is sin plot before real dataset execution to understand basic syntax', color = 'y')
plt.axis('equal')
plt.legend(["green","red"], loc="lower right")
plt.show()

# %%
# Legend function: A legend is a predefined function legend() that creates an area on the graph which describes all the elements of a graph.

plt.figure()
plt.plot(x, np.sin(x+1), color= 'g', label = "X-Axis")
plt.plot(x, np.cos(x+1), color= 'r', label = "Y-Axis")
plt.xlim(1,15)
plt.ylim(-1.5, 1.5)
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.grid(color = 'b')
plt.title('This is sin plot before real dataset execution to understand basic syntax', color = 'y')
plt.axis('equal')
#plt.legend(loc="lower right")  # move lebal from default position to lower right
#plt.legend(loc="lower left")   # move lebal from default position to lower left
#plt.legend(loc="upper left")   # move lebal from default position to upper left
plt.legend(loc="upper right")   # move lebal from default position to upper right
plt.show()

# %%
# Histogram
data = np.random.randn(1000)
plt.hist(data, bins=50, color='y')   # default bins is 10 only
plt.grid(color = 'b')
plt.xlim(1,15)
plt.ylim(-1.5, 1.5)
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.title('This is sin plot before real dataset execution to understand basic syntax', color = 'y')
plt.axis('equal')
#plt.legend(loc="lower right")  # move lebal from default position to lower right
#plt.legend(loc="lower left")   # move lebal from default position to lower left
#plt.legend(loc="upper left")   # move lebal from default position to upper left
plt.legend([["X - Axis","Y - Axis"]],loc="upper right")   # move lebal from default position to upper right
plt.show()

# %%
data1 = np.random.randn(50)
plt.hist(data1, bins=20, color='b')  # Default beans are 10 but we can increase and decrease the beans size
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
x = np.random.randn(50)
y = np.random.randn(50)
plt.figure(figsize=(6,2))
plt.scatter(x,y,  c='r', alpha=.9, marker='X')
plt.title("Scatter Plot")
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.show()

# %%
# Bar Plot
x = ['a','b','c','d','e']
y = [1,2,3,4,5]

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
plt.figure(figsize=(6,2))
plt.bar(x,y, color = 'y')  # It present vertical bar
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis ')
plt.title("Bar Plot")

plt.show()

# %%
plt.figure(figsize=(6,3))
plt.barh(x,y, color = 'b')
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.show()

# %%
# Pai Chart
Marks = [50,60,67,80,90,100]
Subject = ['C', 'C++','JAVA','Python','C#','PHP']
#Student = ['Rajkumar Rajbhar']

# %%
plt.figure()
plt.pie(Marks, Subject,  labels = Subject, autopct = '%1.1f%%')
plt.title('Pie Char')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 plt.figure()
# ----> 2 plt.pie(Marks, Subject,  labels = Subject, autopct = '%1.1f%%')
#       3 plt.title('Pie Char')
#       4 plt.show()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
# ...

# %%
#pie chart

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]
plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie chart")
plt.show()

# %%
x = [1,2,3,4,5]
plt.pie(x)
plt.show()

# %%
Marks = [80, 54,77,80,100]
Students = ['Python', 'Java', 'C', 'C++','PHP']

# %%
Marks
# Out:
# [80, 54, 77, 80, 100]

# %%
Students
# Out:
# ['Python', 'Java', 'C', 'C++', 'PHP']

# %%
plt.pie(Marks, labels=Students, )
plt.show()

# %% [markdown]
# # Start Angle:
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
plt.pie(Marks, labels=Students, startangle=90)
plt.show()

# %%
My_Explode = [.3,0,0,0,0]     # to explod on wedge we use [.3,0,0,0,0] with .3 space but while we explod all wedges from pie char then replace 0 with any number like [.3,.3,.3,.3,.3].
plt.pie(Marks, labels=Students, startangle=90, explode = My_Explode, shadow=True)
plt.show()

# %%
My_Color = ['r','b','y','g','w']
plt.pie(Marks, labels= Students, colors = My_Color)
plt.show()

# %%
My_Color = ['r']
plt.pie(Marks, labels= Students, colors = My_Color)
plt.show()

# %%
My_Color = ['r','b','y','g','w']
f = plt.figure()

f.set_figwidth(10)
f.set_figheight(5)
plt.pie(Marks, labels= Students, colors = My_Color)
plt.legend(loc = 'upper left', title = 'Programing Language')
plt.autoscale(True)
plt.show()

# %%
# 3-D Plot

# %%
x = np.random.randn(20)
y = np.random.randn(20)
z = np.random.randn(20)

# %%
x,y,z
# Out:
# (array([ 1.08244032, -0.39482163, -0.50030587, -0.5998673 ,  1.10272328,
#         -0.51407703, -0.69079536,  1.00850562,  1.54952088,  1.61089896,
#          0.50380363, -1.38694324,  2.41736479,  0.89299959,  0.90583227,
#          1.85006604,  0.19774247,  0.12531322, -0.76653388, -0.3274122 ]),
#  array([-0.46668348, -0.75662589, -1.02350196, -0.41503114,  0.18534025,
#         -2.93311465, -0.67709359,  0.89396585, -0.56215566, -0.27966024,
#          1.13007305, -0.44498366,  0.22653948, -0.60531288,  0.9621113 ,
#          0.63456756,  1.56750668, -2.99940693, -0.41474144,  0.46610315]),
#  array([-1.51784279, -0.81276604, -0.10883965, -0.7408515 ,  0.65352117,
#         -0.53955629,  0.28600189, -2.9783656 , -0.58502635, -0.87033937,
#          1.32504454, -0.91814734,  1.47933982, -0.75651972,  1.32123868,
#         -0.15524837,  1.11722841,  0.9994166 ,  0.38716478, -0.40446453]))

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,x, color = 'r', alpha = .9)
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.show()

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\astral.rajkumar\Desktop\Pandas\Matplotlib & Seaborn\Bank_churn.csv')

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.plot.scatter( x = 'Age', y = 'Balance')

plt.show()

# %%
plt.title('Age Dist')
plt.hist(data['Age'], color = 'g')

plt.title('Balance Dist')
plt.hist(data['Balance'], color = 'y')
plt.show()

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
plt.show()
