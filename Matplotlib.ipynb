# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use("dark_background")

# %%
x = np.random.randn(50)
y = np.random.randn(50)

# %%
x
# Out:
# array([-1.03051793, -0.10503071,  0.12727262,  0.41163092,  0.51896559,
#        -0.0221101 , -0.27571725, -1.06515085, -0.20307794, -1.77385854,
#        -0.47171533,  1.16967735,  2.49685128,  1.92581199,  0.24604043,
#        -0.36394833,  0.30439986, -2.86532658, -1.1506102 , -1.98717948,
#         0.04375507, -0.61744802, -1.43253218,  0.7391574 ,  1.12414248,
#         0.70912234,  0.42570399, -0.10786831,  0.55486946,  0.82674988,
#        -0.59740613,  1.29942258, -2.06482003, -0.56020663, -0.51730346,
#         1.54958803,  0.62644481,  0.41953981,  2.07455902, -0.12811136,
#        -0.01855368,  1.76342138,  0.50615299, -0.58748469,  0.59382914,
#        -0.91172908,  0.24388491, -0.22366615, -0.84343152, -0.01739483])

# %%
y
# Out:
# array([-4.45799817e-01,  4.59528086e-01, -5.80392691e-01,  1.16989181e+00,
#        -5.80616996e-01, -3.28156914e-01,  1.67953456e+00,  1.16444177e+00,
#         1.09184109e+00, -1.45000587e+00,  6.56795687e-01,  6.93178084e-02,
#         5.20527527e-01,  1.88419749e-01, -7.74421081e-01, -5.94752613e-01,
#        -8.32862976e-02, -1.00490215e+00, -1.18939479e+00, -2.29919847e-01,
#        -4.74371531e-01,  1.53597397e-01, -4.12849984e-01,  3.11019226e+00,
#        -2.11940218e-01, -6.69087962e-01, -1.88423255e+00,  3.69897189e-01,
#        -1.01288545e+00,  9.44357481e-01,  6.46134537e-02, -1.13586001e+00,
#        -1.70024490e-01,  1.22015561e+00, -1.72620755e+00, -2.20892701e-01,
#        -2.30567530e-01,  1.02540981e+00, -1.69988720e+00, -1.93893437e-03,
#         3.17485002e-01, -3.21601341e-01,  1.71549378e+00,  1.33634661e+00,
#        -3.96282176e-02, -3.60507833e-02,  6.78375989e-01,  6.29612085e-01,
#         1.61454892e+00, -1.95296864e-01])

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame(np.random.randn(1000), columns=['Data'], index = pd.date_range('13-02-2024', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-02-13 -0.588580
# 2024-02-14 -0.045967
# 2024-02-15  1.285519
# 2024-02-16  0.769908
# 2024-02-17  0.918728
# ...              ...
# 2026-11-04  0.769605
# 2026-11-05 -1.260733
# 2026-11-06 -1.934312
# 2026-11-07  2.488388
# 2026-11-08 -0.390985
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (30,8))
# Out:
# <Axes: >

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y = np.linspace(0,10,100)

# %%
y
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
z = np.linspace(0,10,100)

# %%
z
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.plot(x, np.tan(x))
plt.show()

# %%
plt.plot(y,np.sin(y))
plt.plot(y,np.cos(y))
plt.show()

# %%
plt.plot(x, np.sin(x), '--')
plt.plot(x, np.cos(x), '*')
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x, np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
#plt.plot(x)
plt.plot(x)

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))

plt.subplot(2,2,4)
plt.plot(x, np.tan(x+1))

plt.show()

# %%
plt.figure()           # It will create a new figure or exicuted existing figure
plt.subplot(3,3,1)     # Here we have divided a plot into 3x3 formate where first three is rows and second 3 is columns. 1 indicated as index
plt.plot(x, np.sin(x), '|', color='r') # this is is the main plot

plt.subplot(3,3,2)     # 3-rows, 3-columns and index position is 2
plt.plot(x, np.cos(x), color = 'g')

plt.subplot(3,3,3)     # 3-rows, 3-columns and index position is 3 
plt.plot(x, np.tan(x), color = 'y')

plt.subplot(3,3,4)     # 3-rows, 3-columns and index position is 4
plt.plot(x, np.sin(x+1), color = 'b')

plt.subplot(3,3,5)     # 3-rows, 3-columns and index position is 5
plt.plot(x, np.cos(x+1), color = 'w')

plt.subplot(3,3,6)     # 3-rows, 3-columns and index position is 6
plt.plot(x, np.tan(x+1), color = 'm')

plt.subplot(3,3,7)     # 3-rows, 3-columns and index position is 7
plt.plot(x, np.sin(x+2), color = 'c')

plt.subplot(3,3,8)     # 3-rows, 3-columns and index position is 8
plt.plot(x, np.cos(x+2), color = '#d703fc')

plt.subplot(3,3,9)     # 3-rows, 3-columns and index position is 9
plt.plot(x, np.tan(x+2), color = '#fcad03')

plt.show()

# %%
# Column-wise data representation in plot

plt.figure()
plt.subplot(2,1,1)
plt.plot(x, np.sin(x), scalex=True, scaley=True)

plt.subplot(2,1,2)
plt.plot(x,np.cos(x),scalex=True, scaley=True)

plt.show()

# %%
# scale the plot size

f = plt.figure()

f.set_figwidth(4)
f.set_figheight(1)

plt.subplot(2,1,1)
plt.plot(x, np.sin(x), scalex=True, scaley=True)

plt.subplot(2,1,2)
plt.plot(x,np.cos(x),scalex=True, scaley=True)

plt.show()

# %%
plt.figure()
plt.plot(x,np.sin(x), color = 'r')
plt.xlim(0,15)
plt.ylim(-1.5,1.5)
#plt.axis('equal')
plt.show()

# %%
plt.figure()
plt.plot(x,np.sin(x), color = 'r')
plt.xlim(0,15)
plt.ylim(-1.5,1.5)
plt.axis('equal')
plt.show()
